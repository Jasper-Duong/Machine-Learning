# %%
import os
import tarfile
from six.moves import urllib

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing") #datasets/housing
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH): 
    #Create dir "datasets/housing/housing.tgz"
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    
    #Download dataset to tgz_path
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)

    #Open & Extract .tgz file
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

# %%
HOUSING_PATH
# Out:
# 'datasets/housing'

# %%
fetch_housing_data()

# %%
path = !pwd
path[0]
# Out:
# '/Users/duonghung/JASPER/Study/ML'

# %%
import pandas as pd

df = pd.read_csv(HOUSING_PATH+'/housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(20,15), bins=50)
plt.show()

# %%
import numpy as np

def split_train_test(data, test_ratio):
    
    np.random.seed(42)
    shuffled_indices = np.random.permutation(len(data)) 
    test_set_size = int(len(data) * test_ratio) 
    test_indices = shuffled_indices[:test_set_size] 
    train_indices = shuffled_indices[test_set_size:]
    
    return data.iloc[train_indices], data.iloc[test_indices]

train_data, test_data = split_train_test(df, 0.2)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
# ...

# %% [markdown]
# Although setting random seed will guarantee the same split of the CURRENT Dataset but if the next time I split data on an updated set, the instances that used to be in test would not remained the same.
#
# => Need an identifier that's unique and immutable for each instance => Hash

# %%
from zlib import crc32

def test_set_check(identifier, test_ratio): #identifier will be df's ID => Make sure new data get APPENDED , no rows DELETED
    return crc32(np.int64(identifier)) & 0xffffffff < test_ratio * 2**32 

def split_train_test_by_id(data, test_ratio, column_name):
    ids = data[column_name]

    #check if id in test_set => True/False
    in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio))
    
    return data.loc[~in_test_set], data.loc[in_test_set]

# %%
df_with_id = df.reset_index()
train_set, test_set = split_train_test_by_id(df_with_id, 0.2, "index")

# %%
train_set
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 0          0    -122.23     37.88                41.0        880.0
# 1          1    -122.22     37.86                21.0       7099.0
# 3          3    -122.25     37.85                52.0       1274.0
# 4          4    -122.25     37.85                52.0       1627.0
# 6          6    -122.25     37.84                52.0       2535.0
# ...      ...        ...       ...                 ...          ...
# 20635  20635    -121.09     39.48                25.0       1665.0
# 20636  20636    -121.21     39.49                18.0        697.0
# 20637  20637    -121.22     39.43                17.0       2254.0
# 20638  20638    -121.32     39.43                18.0       1860.0
# 20639  20639    -121.24     39.37                16.0       2785.0
#
#        total_bedrooms  population  households  median_income  \
# 0               129.0       322.0       126.0         8.3252
# ...

# %% [markdown]
# ## sklearn built-in train_test_split

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
# ...

# %% [markdown]
# #### train_set == train_data => train_test_split( ) == split_train_test( )

# %%
train_set == train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196       True      True                True         True            True
# 8267        True      True                True         True            True
# 17445       True      True                True         True            True
# 14265       True      True                True         True            True
# 2271        True      True                True         True            True
# ...          ...       ...                 ...          ...             ...
# 11284       True      True                True         True            True
# 11964       True      True                True         True            True
# 5390        True      True                True         True            True
# 860         True      True                True         True            True
# 15795       True      True                True         True            True
#
# ...

# %% [markdown]
# ### Stratified Sampling
#
# - Maintain categories' ratio in the sample
# - Create category off a numerical attribute: **pd.cut(df[Name of num attr], bins=[ticks], labels [labels_for_each_tick])**

# %%
df['income_categories'] = pd.cut(df['median_income'],
                                bins=[0., 1.5, 3.0, 4.5, 6.0, np.inf],
                                labels=[1, 2, 3, 4, 5])
df['income_categories'].value_counts()
# Out:
# 3    7236
# 2    6581
# 4    3639
# 5    2362
# 1     822
# Name: income_categories, dtype: int64

# %%
df['income_categories'].hist(grid=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### StratifiedShuffleSplit

# %%
from sklearn.model_selection import StratifiedShuffleSplit

#initialize splitter
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

#split for each strat
strat_counter = 1
for train_idx, test_idx in split.split(df, df['income_categories']):
    print(f"Strat {strat_counter}")
    strat_train_set = df.loc[train_idx]
    strat_test_set = df.loc[test_idx]
    strat_counter += 1
    
strat_test_set['income_categories'].value_counts() / len(strat_test_set)
# Out:
# Strat 1
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: income_categories, dtype: float64

# %%
def income_category_ratio(df):
    return df['income_categories'].value_counts() /len(df)

income_category_ratio(df)
# Out:
# 3    0.350581
# 2    0.318847
# 4    0.176308
# 5    0.114438
# 1    0.039826
# Name: income_categories, dtype: float64

# %%
income_category_ratio(strat_train_set)
# Out:
# 3    0.350594
# 2    0.318859
# 4    0.176296
# 5    0.114462
# 1    0.039789
# Name: income_categories, dtype: float64

# %%
for a in (strat_train_set, strat_test_set):
    a.drop("income_categories", axis=1, inplace=True)

# %%
strat_test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5241     -118.39     34.12                29.0       6447.0          1012.0
# 17352    -120.42     34.89                24.0       2020.0           307.0
# 3505     -118.45     34.25                36.0       1453.0           270.0
# 7777     -118.10     33.91                35.0       1653.0           325.0
# 14155    -117.07     32.77                38.0       3779.0           614.0
# ...          ...       ...                 ...          ...             ...
# 12182    -117.29     33.72                19.0       2248.0           427.0
# 7275     -118.24     33.99                33.0        885.0           294.0
# 17223    -119.72     34.44                43.0       1781.0           342.0
# 10786    -117.91     33.63                30.0       2071.0           412.0
# 3965     -118.56     34.19                36.0       2600.0           441.0
#
# ...

# %%
train_set, test_set = train_test_split(df, test_size=0.2, random_state=42, stratify=df['income_categories'])

# %%
income_category_ratio(test_set)
# Out:
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: income_categories, dtype: float64

# %%
income_category_ratio(df)
# Out:
# 3    0.350581
# 2    0.318847
# 4    0.176308
# 5    0.114438
# 1    0.039826
# Name: income_categories, dtype: float64

# %% [markdown]
# ### train_test_split(stratify = cat_column) == StratifiedShuffleSplit( ).split(cat_column)

# %%
test_set.drop('income_categories', axis=1) == strat_test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5241        True      True                True         True            True
# 17352       True      True                True         True            True
# 3505        True      True                True         True            True
# 7777        True      True                True         True            True
# 14155       True      True                True         True            True
# ...          ...       ...                 ...          ...             ...
# 12182       True      True                True         True            True
# 7275        True      True                True         True            True
# 17223       True      True                True         True            True
# 10786       True      True                True         True            True
# 3965        True      True                True         True            True
#
# ...

# %% [markdown]
# ## EDA
#
# ### Geographical Data Visualization

# %%
housing = strat_train_set.copy()

# %%
plt.rcParams["figure.dpi"] = 150

ax = housing.plot(kind='scatter', x='longitude', y='latitude', 
             figsize=(10,7), alpha=0.4,
             cmap='jet', c='median_house_value', 
             label='population', s=housing['population']/100) #label based on column_name chosen for size of instances

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('Population & House Value distribution in California')
plt.legend()
plt.show()

# %%
corr_matrix = housing.corr()

#look up correlation between other attributes and'median_house_value'
corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.687151
# total_rooms           0.135140
# housing_median_age    0.114146
# households            0.064590
# total_bedrooms        0.047781
# population           -0.026882
# longitude            -0.047466
# latitude             -0.142673
# Name: median_house_value, dtype: float64

# %% [markdown]
# **median_income is highly correlated to median_house_value**

# %% [markdown]
# ### Plot pair-wise correlation of numeric attributes with scattered distribution

# %%
from pandas.plotting import scatter_matrix

#pick out the most highly correlated attributes with median_house_value
attr = ['median_income', 'median_house_value', 'total_rooms', 'housing_median_age']
scatter_matrix(housing[attr], figsize=(12,8))
plt.show()

# %%
housing.plot(kind='scatter', 
            x='median_house_value', y='median_income',
            alpha=0.1)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='median_income'>

# %%
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
# ...

# %%
housing['avg_rooms_per_house'] = housing['total_rooms']/housing['households']
housing['avg_bedrooms_per_house'] = housing['total_bedrooms']/housing['households']
housing['pop_per_house'] = housing['population']/housing['households']
housing['bedrooms_per_rooms'] = housing['total_bedrooms']/housing['total_rooms']

attr = ['pop_per_house', 'avg_rooms_per_house', 'avg_bedrooms_per_house', 'median_house_value','bedrooms_per_rooms']
scatter_matrix(housing[attr], figsize=(12,12))
plt.show()

# %%
corr_matrix = housing.corr()
corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value        1.000000
# median_income             0.687151
# avg_rooms_per_house       0.146255
# total_rooms               0.135140
# housing_median_age        0.114146
# households                0.064590
# total_bedrooms            0.047781
# pop_per_house            -0.021991
# population               -0.026882
# avg_bedrooms_per_house   -0.043349
# longitude                -0.047466
# latitude                 -0.142673
# bedrooms_per_rooms       -0.259952
# Name: median_house_value, dtype: float64

# %% [markdown]
# # Data Preparation
#
# ### Data Cleaning - Handle Missing Values
# - Remove attributes having missing values.
#     - ```df.drop(<attr>, axis=1)```
#
# - Remove instances having missing values.
#     - ```df.dropna(subset=[<attr>])```
# - Fill missing values with imputed values (median, mean, zero...)
#     - ```df[<attr>].fillna(<value>, inplace=True)```

# %% [markdown]
# ### Split Labels & Predictors

# %%
df = strat_train_set.drop('median_house_value', axis=1)
df_label = strat_train_set['median_house_value'].copy()

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')

#median only computed on num_attr => drop cat_attr
housing_num = df.drop('ocean_proximity', axis=1)

#compute 'median' for each attr in housing_num => store in '''impute.statistics_'''
imputer.fit(housing_num)

imputer.statistics_
# Out:
# array([-118.51   ,   34.26   ,   29.     , 2119.     ,  433.     ,
#        1164.     ,  408.     ,    3.54155])

# %%
imputer.statistics_ == housing_num.median().values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %%
#transform (i.e replace missing values with imputer)
X = imputer.transform(housing_num)
X
# Out:
# array([[-1.2146e+02,  3.8520e+01,  2.9000e+01, ...,  2.2370e+03,
#          7.0600e+02,  2.1736e+00],
#        [-1.1723e+02,  3.3090e+01,  7.0000e+00, ...,  2.0150e+03,
#          7.6800e+02,  6.3373e+00],
#        [-1.1904e+02,  3.5370e+01,  4.4000e+01, ...,  6.6700e+02,
#          3.0000e+02,  2.8750e+00],
#        ...,
#        [-1.2272e+02,  3.8440e+01,  4.8000e+01, ...,  4.5800e+02,
#          1.7200e+02,  3.1797e+00],
#        [-1.2270e+02,  3.8310e+01,  1.4000e+01, ...,  1.2080e+03,
#          5.0100e+02,  4.1964e+00],
#        [-1.2214e+02,  3.9970e+01,  2.7000e+01, ...,  6.2500e+02,
#          1.9700e+02,  3.1319e+00]])

# %% [markdown]
# ### Handle Text & Categorical Attributes
#
# - Convert text/Categorical values to numbers

# %%
housing_cat = df[['ocean_proximity']]

from sklearn.preprocessing import OrdinalEncoder

ordinal_encoder = OrdinalEncoder()
housing_cat_encoded = ordinal_encoder.fit_transform(housing_cat)
housing_cat_encoded[:10]
# Out:
# array([[1.],
#        [4.],
#        [1.],
#        [4.],
#        [0.],
#        [3.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %% [markdown]
# - List the categorical values -> ```.categories_```

# %%
ordinal_encoder.categories_
# Out:
# [array(['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN'],
#        dtype=object)]

# %% [markdown]
# - ```OrdinalEncoder``` representations have 1 big issue:
#     - ML Algo assume 2 nearby values are more similar than 2 distant values.
#     - It's OK with **ORDINAL** attributes (e.g: 'bad'<'good'<'excellent')
#     - Not OK with **Non-ORDINAL**
# - => ```OneHotEncoder```

# %%
from sklearn.preprocessing import OneHotEncoder

cat_encoder = OneHotEncoder()
housing_cat_1hot = cat_encoder.fit_transform(housing_cat)
housing_cat_1hot
# Out:
# <16512x5 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16512 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Custom Transformer

# %%
from sklearn.base import TransformerMixin, BaseEstimator

# %%
rooms_ix, bedrooms_ix, population_ix, households_ix = 3, 4, 5, 6

class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_bedrooms_per_room = True): # no *args or **kargs
        self.add_bedrooms_per_room = add_bedrooms_per_room 
    def fit(self, X, y=None):
        return self # nothing else to do 
    def transform(self, X, y=None):
        rooms_per_household = X[:, rooms_ix] / X[:, households_ix] 
        population_per_household = X[:, population_ix] / X[:, households_ix] 
        if self.add_bedrooms_per_room:
            bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
            return np.c_[X, rooms_per_household, population_per_household, bedrooms_per_room]
        else:
            return np.c_[X, rooms_per_household, population_per_household]

        
attr_adder = CombinedAttributesAdder(add_bedrooms_per_room=False)
housing_extra_attribs = attr_adder.transform(housing.values)

# %%
housing_extra_attribs
# Out:
# array([[-121.46, 38.52, 29.0, ..., 3.168555240793201, 5.485835694050992,
#         3.168555240793201],
#        [-117.23, 33.09, 7.0, ..., 2.6236979166666665, 6.927083333333333,
#         2.6236979166666665],
#        [-119.04, 35.37, 44.0, ..., 2.223333333333333, 5.3933333333333335,
#         2.223333333333333],
#        ...,
#        [-122.72, 38.44, 48.0, ..., 2.6627906976744184,
#         4.1104651162790695, 2.6627906976744184],
#        [-122.7, 38.31, 14.0, ..., 2.411177644710579, 6.297405189620759,
#         2.411177644710579],
#        [-122.14, 39.97, 27.0, ..., 3.1725888324873095, 5.477157360406092,
#         3.1725888324873095]], dtype=object)

# %% [markdown]
# ### Data Scaling & Transformation Pipelines

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('attr_adder', CombinedAttributesAdder()),
    ('std_scaler', StandardScaler())
])

housing_num_trans = num_pipeline.fit_transform(housing_num)

# %% [markdown]
# - Full PipeLine for bot Num/Cat attributes
#     - ```ColumnTransformer```: apply appropriate transformations to corresponding columns.

# %%
from sklearn.compose import ColumnTransformer

num_attr = list(housing_num)
cat_attr = ['ocean_proximity']

full_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_attr),
    ('cat', OneHotEncoder(), cat_attr)
])

housing_prepared = full_pipeline.fit_transform(housing)

# %% [markdown]
# # Model Training & Selection

# %% [markdown]
# ### Linear Regression - Fit

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(housing_prepared, df_label)
# Out:
# LinearRegression()

# %% [markdown]
# ### Linear Regression - Inference

# %%
some_data = df.iloc[:5]
some_labels = df_label.iloc[:5]

some_data_prepared = full_pipeline.transform(some_data)

print(f"Predictions: {lin_reg.predict(some_data_prepared)}")
print(f"Labels: {list(some_labels)}")
# Out:
# Predictions: [ 86208. 304704. 153536. 185728. 244416.]
# Labels: [72100.0, 279600.0, 82700.0, 112500.0, 238300.0]

# %% [markdown]
# ### Linear Regression - Evaluation RMSE

# %%
from sklearn.metrics import mean_squared_error

housing_predictions = lin_reg.predict(housing_prepared)
lin_mse = mean_squared_error(df_label,housing_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 68633.40810776998

# %% [markdown]
# - Off 40% on training set (```median_housing_value ~$120K -> $265K)```
# #### => Underfitting training data. Reasons:
# - Model is not powerful enough.
# - Features don't provide enough useful info.
#
# #### Solutions
# - Find more powerful models (able to handle nonlinear relationships...)
# - Feed algo with better features.
# - Reduce constraints on the model. (Lin_Reg is not regularized => No constraints to reduce)
#
# ### Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

#Train
tree_reg = DecisionTreeRegressor()
tree_reg.fit(housing_prepared, df_label)

#Predictions => Evaluate
preds = tree_reg.predict(housing_prepared)
tree_mse = mean_squared_error(df_label,preds)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 0.0

# %% [markdown]
# **No error at all? Absolutely perfect?**
# - Badly **OVERFITTING** data?
# > Split Training -> Train/Validation sets
# >> **K-fold-CrossValidation**

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(tree_reg, housing_prepared, df_label,
                        scoring='neg_mean_squared_error', cv=10)

tree_rmse_scores = np.sqrt(-scores)

def display_scores(scores):
    print(f"Scores: {scores}")
    print(f"Mean: {scores.mean()}")
    print(f"Standard Deviation: {scores.std()}") #Measure how precise the evaluation is
    
display_scores(tree_rmse_scores)
# Out:
# Scores: [72842.1955669  72478.41288064 69687.41178582 71403.83810826
#  69749.98033108 77609.5899644  69372.51006994 74264.59347258
#  67369.00475452 71638.35155901]
# Mean: 71641.58884931411
# Standard Deviation: 2747.656120111871

# %%
lin_scores = cross_val_score(lin_reg, housing_prepared, df_label,
                            scoring='neg_mean_squared_error', cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [71800.38078269 64114.99166359 67844.95431254 68635.19072082
#  66801.98038821 72531.04505346 73992.85834976 68824.54092094
#  66474.60750419 70143.79750458]
# Mean: 69116.4347200802
# Standard Deviation: 2880.6588594759014

# %% [markdown]
# ### Random Forest Regressor
#
# - Train many DecisionTrees on **random subsets of features**.
# - Average the predictions.
# - ***Ensemble Learning***: Building a model on top of many other models.

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor()
forest_reg.fit(housing_prepared, df_label)

forest_scores = cross_val_score(forest_reg, housing_prepared, df_label,
                               scoring='neg_mean_squared_error', cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)
display_scores(forest_rmse_scores)
# Out:
# Scores: [51198.42421147 49241.72445731 46925.65558233 51896.60577148
#  47094.68191579 51767.58882622 52888.09243902 49526.95482442
#  48084.31558538 54052.47114381]
# Mean: 50267.65147572313
# Standard Deviation: 2335.9366123019217

# %%
forest_preds = forest_reg.predict(housing_prepared)
forest_rsme = np.sqrt(mean_squared_error(forest_preds, df_label))
print("RSME on Training set: ", forest_rsme)
# Out:
# RSME on Training set:  18736.057765661506

# %% [markdown]
# - Score on Val (50K) vs Train (18K): Large margin
#
# => <strong> Overfitting on Train </strong>
#
# - Solutions for Overfitting:
#     - Simplify model.
#     - Constrain (Regularize) model.
#     - Get more training data.

# %% [markdown]
# ## Save model

# %%
# from sklearn.externals import joblib

# joblib.dump(my_model, 'my_model.pkl')

# my_model_loaded = joblib.load('my_model.pkl')

# %% [markdown]
# # Fine Tune Model
# ## Grid Search

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    {'n_estimators':[3, 10, 30], 
     'max_features':[2, 4, 6, 8]},
    
    {'bootstrap':[False],
     'n_estimators':[3, 10], 
     'max_features':[2, 3, 4]}
]

forest_reg = RandomForestRegressor()
grid_search = GridSearchCV(estimator = forest_reg,
                           param_grid = param_grid,
                           cv=5, scoring='neg_mean_squared_error',
                           return_train_score=True)

grid_search.fit(housing_prepared, df_label)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'max_features': 6, 'n_estimators': 30}

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=6, n_estimators=30)

# %%
cv_results = grid_search.cv_results_

for mean_score, params in zip(cv_results['mean_test_score'], cv_results['params']):
        print(np.sqrt(-mean_score), params)
# Out:
# 64827.08034974772 {'max_features': 2, 'n_estimators': 3}
# 55495.41290755001 {'max_features': 2, 'n_estimators': 10}
# 52536.70343633362 {'max_features': 2, 'n_estimators': 30}
# 60434.401966290294 {'max_features': 4, 'n_estimators': 3}
# 52952.79382802784 {'max_features': 4, 'n_estimators': 10}
# 50411.89323415802 {'max_features': 4, 'n_estimators': 30}
# 58358.06857430278 {'max_features': 6, 'n_estimators': 3}
# 51928.0064697898 {'max_features': 6, 'n_estimators': 10}
# 49829.10111257753 {'max_features': 6, 'n_estimators': 30}
# 59004.322536555635 {'max_features': 8, 'n_estimators': 3}
# 52400.33069311882 {'max_features': 8, 'n_estimators': 10}
# 50184.47784961339 {'max_features': 8, 'n_estimators': 30}
# 61890.270367291436 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 54032.780715450936 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 60306.183981258684 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# ...

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
feature_importances
# Out:
# array([7.75923966e-02, 7.06032049e-02, 4.07104673e-02, 1.85496066e-02,
#        1.68172490e-02, 1.79797810e-02, 1.57253772e-02, 3.16033680e-01,
#        4.97503027e-02, 1.07999661e-01, 8.92945680e-02, 7.44440260e-03,
#        1.63805044e-01, 9.80663392e-05, 4.18192157e-03, 3.41427065e-03])

# %%
extra_attr = ["rooms_per_hhold", "pop_per_hhold", "bedrooms_per_room"]
cat_encoder = full_pipeline.named_transformers_['cat']
cat_one_hot_attr = list(cat_encoder.categories_[0])

#Order of transformed set: num_attr + combined_num_attr + cat_1_hot_attr
attributes = num_attr + extra_attr + cat_one_hot_attr
attributes
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'rooms_per_hhold',
#  'pop_per_hhold',
#  'bedrooms_per_room',
#  '<1H OCEAN',
#  'INLAND',
#  'ISLAND',
#  'NEAR BAY',
#  'NEAR OCEAN']

# %%
#Descending feature importances
sorted(zip(feature_importances, attributes), reverse=True)
# Out:
# [(0.31603368006407434, 'median_income'),
#  (0.1638050441760277, 'INLAND'),
#  (0.10799966143451824, 'pop_per_hhold'),
#  (0.08929456795386713, 'bedrooms_per_room'),
#  (0.07759239658819074, 'longitude'),
#  (0.07060320486001309, 'latitude'),
#  (0.04975030273902502, 'rooms_per_hhold'),
#  (0.04071046729299733, 'housing_median_age'),
#  (0.01854960659677598, 'total_rooms'),
#  (0.01797978100256938, 'population'),
#  (0.016817248969100772, 'total_bedrooms'),
#  (0.01572537715759818, 'households'),
#  (0.007444402604669211, '<1H OCEAN'),
#  (0.0041819215683974184, 'NEAR BAY'),
#  (0.003414270652946455, 'NEAR OCEAN'),
#  (9.806633922908724e-05, 'ISLAND')]

# %% [markdown]
# ## Evaluate on Test Set

# %%
final_model = grid_search.best_estimator_

X_test = strat_test_set.drop("median_house_value", axis=1)
y_test = strat_test_set['median_house_value'].copy()

#Transform test data, NOT fit_transform() -> Don't want model to fit on test set
X_test_prepared = full_pipeline.transform(X_test)

final_predictions = final_model.predict(X_test_prepared)

final_rmse = np.sqrt(mean_squared_error(y_test, final_predictions))

print(f"RMSE on Test set: {final_rmse}")
# Out:
# RMSE on Test set: 47721.2659384953

# %% [markdown]
# - A performance score (generalization error) is not enough to express how precise the estimations are.
#
# <strong> => 95% Confidence interval </strong>

# %%
from scipy import stats

confidence = 0.95
squared_error = (final_predictions - y_test)**2
np.sqrt(stats.t.interval(confidence, len(squared_error) - 1,
                         loc=squared_error.mean(),
                         scale=stats.sem(squared_error)
))
# Out:
# array([45728.0217247, 49634.5290568])
